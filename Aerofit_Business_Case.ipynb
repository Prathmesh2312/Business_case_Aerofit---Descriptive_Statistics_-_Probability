# %% [markdown]
# # 🧾Aerofit Business Case Study
# Aerofit is a leading brand in the field of fitness equipment. Aerofit provides a product range including machines such as treadmills, exercise bikes, gym equipment, and fitness accessories to cater to the needs of all categories of people.

# %% [markdown]
# ## ❓Business Problem
# The market research team at AeroFit wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("Aerofit_treadmill.csv")

# %%
print("First few rows of dataset")
df.head()
# Out:
# First few rows of dataset
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
print("Number of Rows and Columns present in Dataset:")
df.shape
# Out:
# Number of Rows and Columns present in Dataset:
# (180, 9)

# %% [markdown]
# ### 📊Statistical Information about Dataset

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# ### ⚠️ Outliers Present in the dataset
# Used Boxplot to visualize and detect outliers for numerical features like Age, Income, Miles & Usage

# %%
# BoxPlot for Age
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["Age"])
plt.title("Boxplot of Age")
plt.show()

# %% [markdown]
# #### 🔍 Insights
# * Most customers who purchase treadmills fall between 22 and 40 years old.
# * A small group of older customers (ages 47–50) might represent fitness enthusiasts or individuals who prefer high-quality treadmills like KP781.

# %%
# Boxplot for Income
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["Income"])
plt.title("Boxplot of Income")
plt.show()

# %% [markdown]
# ### 🔍 Insights
# * Most customers have incomes between 40,000 and 70,000, forming the core target audience.
# * Customers with incomes above 75,000 are outliers, but they represent a niche, high-income group.
# * This group of high-income customers might be more likely to purchase premium products like the KP781 treadmill, which has advanced features and sells for 2,500.

# %%
# Boxplot for Miles
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["Miles"])
plt.title("Boxplot of Miles")
plt.show()

# %% [markdown]
# #### 🔍 Insights
# * Most users log between 50 and 150 miles, forming the primary usage range.
# * This segment represents consistent treadmill usage by regular customers.
# * The outliers with values above 180 miles highlight a niche group of extreme users.
# * These individuals may have higher fitness goals or performance demands, such as athletes or fitness enthusiasts.

# %%
# Boxplot for Usage
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["Usage"])
plt.title("Boxplot of Usage")
plt.show()

# %% [markdown]
# #### 🔍 Insights
# * Most customers use the treadmill between 2 and 5 days per week, forming the primary usage group.
# * This segment likely includes moderate users who seek consistent but not extreme fitness routines.
# * Outliers with usage values of 6 and 7 days per week represent highly dedicated users.

# %%
print(df[['Age', 'Income', 'Miles', 'Usage']].describe())
# Out:
#               Age         Income       Miles       Usage
# count  180.000000     180.000000  180.000000  180.000000
# mean    28.788889   53719.577778  103.194444    3.455556
# std      6.943498   16506.684226   51.863605    1.084797
# min     18.000000   29562.000000   21.000000    2.000000
# 25%     24.000000   44058.750000   66.000000    3.000000
# 50%     26.000000   50596.500000   94.000000    3.000000
# 75%     33.000000   58668.000000  114.750000    4.000000
# max     50.000000  104581.000000  360.000000    7.000000

# %%
sns.countplot(x="Product", data=df)
plt.title("Distribution of Treadmill Products Purchased")
plt.show()

# %% [markdown]
# #### 🔍 Insights
# * KP281 has the highest share, it indicates demand for affordable, entry-level products.
# * KP481 is the second most popular model as it comes in mid-range. It was purchased 60 times.
# * KP781 (the premium model) has the lowest count, which reflects that fewer customers prefer high-end models.

# %%
sns.countplot(x="MaritalStatus", hue="Product", data=df)
plt.title("Marital Status vs Product Purchased")
plt.show()

# %% [markdown]
# #### 🔍 Insights
# * Partnered customers may dominate the purchase of KP781 due to higher household income or shared fitness goals.
# * Single customers may purchase KP281 or KP481 based on personal fitness needs and affordability.

# %%
sns.boxplot(x="Product", y="Age", data=df)
plt.title("Age Distribution by Product Purchased")
plt.show()

# %% [markdown]
# #### 🔍 Insights
# * KP281 is most popular among younger customers (early 20s–30s), likely due to budget constraints.
# * KP481 appeals to customers in their 30s, indicating a balance between price and performance.
# * KP781 attracts older customers (35–45 years) with higher purchasing power who seek premium features.

# %% [markdown]
# ###  Probabilities

# %%
contingency_table = pd.crosstab(df["Product"], df["Gender"], normalize="all")
contingency_table
# Out:
# Gender     Female      Male
# Product
# KP281    0.222222  0.222222
# KP481    0.161111  0.172222
# KP781    0.038889  0.183333

# %% [markdown]
# #### 🔍 Insights
# 1) KP281
#    * 22.22% of customers who purchased this product are Female.
#    * 22.22% of customers who purchased this product are Male.
#    * This indicates that KP281 has an equal gender split, suggesting it appeals equally to males and females.
# 2) KP481
#    * 16.11% of customers are Female.
#    * 17.22% of customers are Male.
#    * Although the proportions are close, KP481 has slightly higher representation among male customers.
# 3) KP781
#    * 3.89% of customers are Female.
#    * 18.33% of customers are Male.
#    * KP781 has a significant male dominance in purchases. More males are buying this advanced treadmill compared to females.

# %% [markdown]
# #### Marginal Probabilities

# %%
marginal = pd.crosstab(df["Product"], "Total", normalize="all")
marginal
# Out:
# col_0       Total
# Product
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222

# %% [markdown]
# #### 🔍 Insights
# 1) KP281
#    * 44.44% of all customers purchased the KP281 treadmill.
#    * This is the most popular product in terms of overall purchases, indicating that it appeals to a wide range of customers due to its affordability and features.
# 2) KP481
#    * 33.33% of all customers purchased the KP481 treadmill.
#    * While not as popular as the KP281, it still captures a significant portion of the market. This treadmill likely appeals to customers looking for mid-level performance and features.
# 3) KP781
#    * 22.22% of all customers purchased the KP781 treadmill.
#    * This is the least purchased treadmill in the dataset, but it may still represent the premium segment, with customers willing to invest in higher-end features.

# %% [markdown]
# #### Conditional Probabilities

# %%
conditional = pd.crosstab(df["Product"], df["Gender"], normalize="index")
conditional
# Out:
# Gender     Female      Male
# Product
# KP281    0.500000  0.500000
# KP481    0.483333  0.516667
# KP781    0.175000  0.825000

# %% [markdown]
# #### 🔍 Insights
# 1) KP281
#    * 50% of female customers bought the KP281 treadmill.
#    * 50% of male customers bought the KP281 treadmill.
#    * Interpretation: KP281 has equal gender appeal. It’s likely an entry-level product that appeals to a broad demographic, with no gender preference. The product's affordability and features attract both male and female customers equally.
# 2) KP481
#    * 48.33% of female customers purchased the KP481 treadmill.
#    * 51.67% of male customers purchased the KP481 treadmill.
#    * Interpretation: There is a slightly higher preference for males in purchasing KP481, but it is still fairly balanced. This could indicate that the product is appealing to both male and female customers, but males may be marginally more interested in mid-range fitness equipment.
# 3) KP781
#    * 17.5% of female customers bought the KP781 treadmill.
#    * 82.5% of male customers bought the KP781 treadmill.
#    * Interpretation: KP781 is very male-dominated. It’s a high-end treadmill, and its advanced features or price likely appeal more to male customers who are more serious about fitness or willing to invest in a top-tier product.lly.

# %%
numerical_df = df.select_dtypes(include=["number"])
plt.figure(figsize=(10, 6))
sns.heatmap(numerical_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #### 🔍 Insights
# 1) Strong Positive Correlations:
#    * Income vs Fitness: A strong positive correlation close to 1 indicates that individuals with higher fitness levels also tend to have higher incomes.
#    * Miles vs Fitness: Miles and Fitness have a high positive correlation. This suggests that customers who walk or run more miles also have higher fitness levels.
#    * Income vs Miles: Income and Miles also have a positive correlation, meaning people with higher incomes tend to cover more miles.
# 2) Weak Correlations:
#    * Age vs Miles: There is a very weak correlation (~0.037) between Age and Miles, suggesting age does not strongly influence the number of miles walked.
#    * Age vs Usage: Similarly, Age and Usage have a near-zero correlation (~0.015), indicating that age has no significant relationship with the frequency of product usage.
# 3) Moderate Correlation:
#    * Age vs Income: A moderate correlation (~0.51) suggests that older individuals might have higher incomes, which could be attributed to career progression over time.
# 4) Education:
#    * Education has moderate correlations with Income and Fitness, indicating that higher education levels might have some influence on fitness and income but not very strongly.

# %%
sns.pairplot(df, hue="Product", diag_kind="hist") 
plt.suptitle("Pair Plot of Numerical Features by Product Purchased", y=1.02)
plt.show()
# Out:
# C:\Users\victus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\victus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\victus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# #### 🔍 Insights
# 1) Diagonal (Histograms):
#    * Each diagonal shows the distribution (via histograms) of individual numerical features, separated by Product Purchased.
#    * For instance:
#      * Age: The majority of customers are younger (20-30 years), and KP781 is more prevalent in younger groups.
#      * Income: Income is skewed with most customers earning below 70,000, but KP781 customers show higher income levels.
# 2) Scatter Plots:
#    * Off-diagonal scatter plots display the relationship between pairs of numerical variables.
#    * Age vs Income:
#      * A positive trend is visible—older customers tend to have higher incomes.
#      * KP781 (green) customers are mostly high-income individuals, indicating income plays a role in this purchase.
#    * Miles vs Fitness:
#      * KP781 users tend to have higher miles and fitness levels, suggesting this product caters to high-usage and fitness-oriented customers.
#    * Usage vs Income:
#      * KP781 (green) shows higher income levels and also correlates with higher treadmill usage.
# 3) Product Trends (Hue):
#    * KP281 (blue): Appears across all income and age levels but is more common among low-to-moderate income groups.
#    * KP481 (orange): Spans a middle range of age and income.
#    * KP781 (green): Dominates in high-income, high-usage, and higher fitness-level customers.

# %% [markdown]
# ### 🕵️‍♀️ Customer Profiling
# Based on your analysis of the dataset, I have created detailed customer profiles for each treadmill product: KP281, KP481, and KP781.

# %% [markdown]
# #### 1) KP281: Entry-Level Treadmill
# * Target Customers:
#   Younger individuals with lower income, moderate fitness levels, and limited weekly usage.
# * Case Study Observations:
#   1) Age:
#      * In the Age vs Product Purchased boxplot, KP281 is purchased by younger individuals (early 20s to early 30s).
#      * The pair plot histograms confirm this as the Age distribution for KP281 skews left (towards younger customers).
#   2) Income:
#      * Customers purchasing KP281 tend to have lower income levels (visible in scatter plots of Age vs Income and Income vs Miles).
#      * This suggests KP281 is affordable and attractive to budget-conscious customers.
#   3) Fitness and Usage:
#      * Fitness scores and usage (miles covered weekly) are moderate.
#      * Scatter plots (Usage vs Fitness and Miles vs Income) show KP281 customers are not heavy treadmill users compared to KP481 and KP781 buyers.
#      * Weekly mileage is lower, suggesting limited use, likely for entry-level workouts.

# %% [markdown]
# #### 2) KP481: Mid-Range Treadmill
# * Target Customers: Middle-aged individuals with moderate-to-high fitness levels and moderate income.
# * Case Study Observations:
#   1) Age:
#      * KP481 is purchased primarily by middle-aged individuals (late 30s to early 50s).
#      * In the boxplots and pair plots, the Age distribution for KP481 shows a broader spread compared to KP281.
#   2) Income:
#      * Customers have moderate income levels.
#      * Income is higher than KP281 buyers but not as high as KP781 customers (evident in Income scatter plots).
#   3) Fitness and Usage:
#      * KP481 buyers show higher fitness levels and usage compared to KP281 customers.
#      * Weekly treadmill usage is moderate, suggesting they use the treadmill consistently but not excessively.
#      * This positions KP481 as suitable for regular users who are serious about fitness but not necessarily elite enthusiasts.

# %% [markdown]
# #### 3) KP781: Advanced Treadmill
# * Target Customers: Older individuals or fitness enthusiasts with high income, high fitness ratings, and extensive treadmill usage.
# * Case Study Observations:
#   1) Age:
#      * KP781 buyers tend to be older individuals or fitness enthusiasts (50+ age group).
#      * This is clear from the Age boxplots and scatter plots, where KP781 customers have a higher median age compared to KP281 and KP481.
#   2) Income:
#      * KP781 customers have high income levels.
#      * In scatter plots (Age vs Income and Income vs Miles), KP781 buyers are concentrated at the higher end of the income scale.
#   3) Fitness and Usage:
#      * KP781 buyers show the highest fitness scores and weekly usage (miles covered).
#      * The Fitness vs Miles scatter plots highlight their higher treadmill usage, suggesting a focus on intense or frequent workouts.
#      * KP781 is likely purchased by fitness enthusiasts or customers who require premium treadmill features.

# %% [markdown]
# #### ✔️Conclusion
# By analyzing the numerical features and relationships from the dataset:
# 1) KP281: Targets younger, budget-conscious individuals with moderate fitness and limited treadmill usage.
# 2) KP481: Attracts middle-aged individuals with moderate income and consistent fitness usage.
# 3) KP781: Appeals to older or high-income fitness enthusiasts with high fitness ratings and extensive treadmill usage.

# %% [markdown]
# ### 👉 Recommendations

# %% [markdown]
# #### 1) KP281: Entry-Level Treadmill
# 1) Affordable Financing Options:
#    * Highlight installment plans, discounts, and affordable pricing to attract budget-conscious younger individuals.
#    * Position KP281 as an entry-level treadmill for first-time buyers.
# 2) Focus on Basic Features:
#    * Emphasize features like ease of use, compact design, and affordability.
#    * Avoid marketing complex, high-end features that may not resonate with this customer base.
# 3) Student and Beginner Campaigns:
#    * Offer promotional campaigns targeted at students and young professionals (e.g., “Start Your Fitness Journey”).

# %% [markdown]
# #### 2) KP481: Mid-Range Treadmill
# 1) Highlight Value for Money:
#    * Emphasize KP481 as a balance between affordability and premium features. Position it as a reliable, durable treadmill for regular use.
#    * Showcase its benefits for maintaining a healthy lifestyle without needing a high investment.

# %% [markdown]
# #### 3) KP781: Advanced Treadmill
# 1) Premium Positioning:
#    * Position KP781 as a high-end, advanced treadmill for fitness enthusiasts and high-income individuals.
#    * Highlight premium features such as: * High durability * Advanced workout programs * Smart features (e.g., heart rate monitors, performance tracking)
# 2) Advanced Training Campaigns:
#    * Offer video tutorials, webinars, and personalized programs for KP781 users to maximize their workouts.
# 3) Luxury Branding and Marketing:
#    * Advertise in premium fitness magazines, high-end online platforms, and health clubs.
#    * Position KP781 as a status symbol for those who value fitness and wellness.
